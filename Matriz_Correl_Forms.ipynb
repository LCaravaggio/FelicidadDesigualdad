# %% [markdown]
# <a href="https://colab.research.google.com/github/LCaravaggio/FelicidadDesigualdad/blob/main/Matriz_Correl_Forms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/respuestas forms.csv', sep=';')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Matriz de correlación
corr_matrix = data.corr(method="pearson")
print("Matriz de correlación:")
print(corr_matrix)

# Visualización como heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap="Blues", fmt=".2f", square=True)
plt.title("Matriz de Correlación", fontsize=14)
plt.show()
# Out:
# Matriz de correlación:
#                   Gini       5km      10km  Respuestas 1  Respuestas 2  \
# Gini          1.000000  0.351609  0.307979      0.761177      0.506191
# 5km           0.351609  1.000000  0.851597      0.389315      0.484492
# 10km          0.307979  0.851597  1.000000      0.444889      0.412600
# Respuestas 1  0.761177  0.389315  0.444889      1.000000      0.533908
# Respuestas 2  0.506191  0.484492  0.412600      0.533908      1.000000
# Respuestas 3  0.713349  0.312386  0.339037      0.726750      0.495491
# Respuestas 4  0.322045  0.373357  0.512638      0.245098      0.458448
# Respuestas 5  0.533864  0.440123  0.378938      0.620286      0.664817
# Promedio      0.726931  0.523937  0.575227      0.784102      0.795312
#
#               Respuestas 3  Respuestas 4  Respuestas 5  Promedio
# Gini              0.713349      0.322045      0.533864  0.726931
# 5km               0.312386      0.373357      0.440123  0.523937
# ...
